# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series(np.random.randn(4),name='daily returnd')
s
# Out:
# 0    0.949047
# 1   -0.475337
# 2   -0.601831
# 3    0.280057
# Name: daily returnd, dtype: float64

# %%
np.abs(s)#返回绝对值
# Out:
# 0    0.949047
# 1    0.475337
# 2    0.601831
# 3    0.280057
# Name: daily returnd, dtype: float64

# %%
s.describe()
# s.describe(percentiles="设定数值型特征的统计量，默认为【。25，。5，。75】，也就是返回25%，50%，75%数据量时的数字0"
#            ，Parch这一列代表父母与孩子的比例，
#            include，这个参数默认是只计算数值型特征的统计量，当输入include=['O']，
#            会计算离散型变量的统计特征)
#标准差
# Out:
# count    4.000000
# mean     0.037984
# std      0.721456
# min     -0.601831
# 25%     -0.506961
# 50%     -0.097640
# 75%      0.447304
# max      0.949047
# Name: daily returnd, dtype: float64

# %%
s
# Out:
# 0    0.949047
# 1   -0.475337
# 2   -0.601831
# 3    0.280057
# Name: daily returnd, dtype: float64

# %%
s.index=['a','b','c','d']
s
# Out:
# a    0.949047
# b   -0.475337
# c   -0.601831
# d    0.280057
# Name: daily returnd, dtype: float64

# %%
s['a']
# Out:
# 0.9490471931755919

# %%
s['b']
# Out:
# -0.47533705360107814

# %%
'a' in s
# Out:
# True

# %%
df=pd.read_csv('https://github.com/QuantEcon/QuantEcon.lectures.code/blob/master/pandas/data/test_pwt.csv')
df
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# d:\python3.7\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# d:\python3.7\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# d:\python3.7\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ...

# %%
# %pwd
# Out:
# 'C:\\Users\\86183\\Desktop\\pandas'

# %%
data=pd.read_csv('test.csv')

# %%
data
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
data[2:6]
# Out:
#         country country isocode  year          POP       XRAT         tcgdp  \
# 2         India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3        Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4        Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5  South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
#
#           cc         cg
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546

# %%
data[['country','tcgdp']]
# Out:
#          country         tcgdp
# 0      Argentina  2.950722e+05
# 1      Australia  5.418047e+05
# 2          India  1.728144e+06
# 3         Israel  1.292539e+05
# 4         Malawi  5.026222e+03
# 5   South Africa  2.272424e+05
# 6  United States  9.898700e+06
# 7        Uruguay  2.525596e+04

# %%
data.iloc[1:7]
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
#
#           cc         cg
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454

# %%
data.iloc[ 1:6 ,0:4]
# Out:
#         country country isocode  year          POP
# 1     Australia             AUS  2000    19053.186
# 2         India             IND  2000  1006300.297
# 3        Israel             ISR  2000     6114.570
# 4        Malawi             MWI  2000    11801.505
# 5  South Africa             ZAF  2000    45064.098

# %%
data.loc[data.index[1:5],['country','year']]
# Out:
#      country  year
# 1  Australia  2000
# 2      India  2000
# 3     Israel  2000
# 4     Malawi  2000

# %%
data['country','POP']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python3.7\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country', 'POP')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-af022008b7ab> in <module>
# ----> 1 data['country','POP']
#
# ...

# %%
data
# Out:
#          country country isocode  year          POP       XRAT         tcgdp  \
# 0      Argentina             ARG  2000    37335.653   0.999500  2.950722e+05
# 1      Australia             AUS  2000    19053.186   1.724830  5.418047e+05
# 2          India             IND  2000  1006300.297  44.941600  1.728144e+06
# 3         Israel             ISR  2000     6114.570   4.077330  1.292539e+05
# 4         Malawi             MWI  2000    11801.505  59.543808  5.026222e+03
# 5   South Africa             ZAF  2000    45064.098   6.939830  2.272424e+05
# 6  United States             USA  2000   282171.957   1.000000  9.898700e+06
# 7        Uruguay             URY  2000     3219.793  12.099592  2.525596e+04
#
#           cc         cg
# 0  75.716805   5.578804
# 1  67.759026   6.720098
# 2  64.575551  14.072206
# 3  64.436451  10.266688
# 4  74.707624  11.658954
# 5  72.718710   5.726546
# 6  72.347054   6.032454
# 7  78.978740   5.108068

# %%
data
# Out:
#               country isocode  year          POP       XRAT         tcgdp  \
# country
# Argentina                 ARG  2000    37335.653   0.999500  2.950722e+05
# Australia                 AUS  2000    19053.186   1.724830  5.418047e+05
# India                     IND  2000  1006300.297  44.941600  1.728144e+06
# Israel                    ISR  2000     6114.570   4.077330  1.292539e+05
# Malawi                    MWI  2000    11801.505  59.543808  5.026222e+03
# South Africa              ZAF  2000    45064.098   6.939830  2.272424e+05
# United States             USA  2000   282171.957   1.000000  9.898700e+06
# Uruguay                   URY  2000     3219.793  12.099592  2.525596e+04
#
#                       cc         cg
# country
# Argentina      75.716805   5.578804
# Australia      67.759026   6.720098
# India          64.575551  14.072206
# Israel         64.436451  10.266688
# Malawi         74.707624  11.658954
# South Africa   72.718710   5.726546
# ...

# %%
# Out:
#                        POP         tcgdp
# country
# Argentina        37335.653  2.950722e+05
# Australia        19053.186  5.418047e+05
# India          1006300.297  1.728144e+06
# Israel            6114.570  1.292539e+05
# Malawi           11801.505  5.026222e+03
# South Africa     45064.098  2.272424e+05
# United States   282171.957  9.898700e+06
# Uruguay           3219.793  2.525596e+04

# %%
data.columns='population','total gdp'
data
# Out:
#                 population     total gdp
# country
# Argentina        37335.653  2.950722e+05
# Australia        19053.186  5.418047e+05
# India          1006300.297  1.728144e+06
# Israel            6114.570  1.292539e+05
# Malawi           11801.505  5.026222e+03
# South Africa     45064.098  2.272424e+05
# United States   282171.957  9.898700e+06
# Uruguay           3219.793  2.525596e+04

# %%
data['population']=data['population']*1000
data['total gdp']=data['total gdp']*1000000
data['gdp percap']=data['total gdp']/data['population']
data
# Out:
#                  population     total gdp    gdp percap
# country
# Argentina      3.733565e+10  2.950722e+17  7.903229e+06
# Australia      1.905319e+10  5.418047e+17  2.843643e+07
# India          1.006300e+12  1.728144e+18  1.717325e+06
# Israel         6.114570e+09  1.292539e+17  2.113867e+07
# Malawi         1.180150e+10  5.026222e+15  4.258967e+05
# South Africa   4.506410e+10  2.272424e+17  5.042648e+06
# United States  2.821720e+11  9.898700e+18  3.508038e+07
# Uruguay        3.219793e+09  2.525596e+16  7.843971e+06

# %%
import matplotlib.pyplot as plt

# %%
data['gdp percap'].plot(kind='bar')
plt.show()

# %%
data=data.sort_values(by='gdp percap',ascending=True)
data
# Out:
#                  population     total gdp    gdp percap
# country
# Malawi         1.180150e+10  5.026222e+15  4.258967e+05
# India          1.006300e+12  1.728144e+18  1.717325e+06
# South Africa   4.506410e+10  2.272424e+17  5.042648e+06
# Uruguay        3.219793e+09  2.525596e+16  7.843971e+06
# Argentina      3.733565e+10  2.950722e+17  7.903229e+06
# Israel         6.114570e+09  1.292539e+17  2.113867e+07
# Australia      1.905319e+10  5.418047e+17  2.843643e+07
# United States  2.821720e+11  9.898700e+18  3.508038e+07

# %%
data['gdp percap'].plot(kind='bar')
plt.show()
